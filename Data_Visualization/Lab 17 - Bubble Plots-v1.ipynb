# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bubble Plots**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be directly loaded into pandas for analysis and visualization.
#
# You will use various visualization techniques to explore the data and uncover key trends.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two data features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# #### Setup: Working with the Database
# **Install and import the needed libraries**

# %%
# !pip install pandas 
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
# --2026-09-07 01:47:16--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  36.8MB/s    in 5.0s
#
# 2026-09-07 01:47:22 (30.7 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Exploring Data Distributions Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Age vs. Frequency of Participation

# %% [markdown]
# - Visualize the relationship between respondents’ age and their participation frequency (`SOPartFreq`) using a bubble plot.
#
# - Use the size of the bubbles to represent their job satisfaction (`JobSat`).

# %%
##Write your code here
df_1 = df[['JobSat', 'Age', 'SOPartFreq']]
df_1.dropna(inplace=True)
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}

df_1['Age'] = df_1['Age'].map(age_mapping)
df_1['JobSatCode'] = df_1['JobSat'].astype('category').cat.codes

plt.figure(figsize=(12, 6))
plt.scatter(df_1['Age'], 
            df_1['SOPartFreq'],
            s=df_1['JobSat'],
            alpha=0.5)

plt.title('BubblePlot: Participation Freq vs Age with Bubble Size: Job Sat')
plt.ylabel('SOPartFreq')
plt.xlabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/3124893890.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.dropna(inplace=True)
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/3124893890.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Age'] = df_1['Age'].map(age_mapping)
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/3124893890.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### 2. Bubble Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# -Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSat`).
#
# - Use the size of the bubbles to represent respondents’ age.

# %%
##Write your code here
df_2 = df[['JobSat', 'Age', 'ConvertedCompYearly']]
df_2.dropna(inplace=True)

df_2['Age'] = df_2['Age'].astype(str).map(age_mapping)
df_2['Age'] = df_2['Age'].astype(float)
upper = df_2['ConvertedCompYearly'].quantile(0.99)
df_new5 = df_2[df_2['ConvertedCompYearly'] <= upper]

plt.figure(figsize=(12, 6))
plt.scatter(df_2['ConvertedCompYearly'], 
            df_2['JobSat'],
            s=df_2['Age'] * 3,
            alpha=0.5)

plt.title('BubblePlot: Yearly Comp vs Job Sat with Bubble Size: Age')
plt.ylabel('JobSat')
plt.xlabel('ConvertedCompYearly')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/2682694232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dropna(inplace=True)
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/2682694232.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Age'] = df_2['Age'].astype(str).map(age_mapping)
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/2682694232.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Task 2: Analyzing Relationships Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot of Technology Preferences by Age
#
# - Visualize the popularity of programming languages respondents have worked with (`LanguageHaveWorkedWith`) across age groups.
#
# - Use bubble size to represent the frequency of each language.

# %%
##Write your code here
import numpy as np
df_3 = df[['LanguageHaveWorkedWith', 'Age']]
df_3['Language'] = df_3['LanguageHaveWorkedWith'].str.split(';')
df_3 = df_3.explode('Language')
df_3['Language'] = df_3['Language'].str.strip()

df_3.dropna(inplace=True)

age_order = ["Under 18", "18-24", "25-34", "35-44", "45-54", "55-64", "65+"]

df_3['Age'] = df_3['Age'].map(age_mapping)
lang_counts = (
    df_3.groupby(['Age', 'Language'], as_index=False)
    .size()
    .rename(columns={'size': "Count"})
)
age_to_x = {age: i for i, age in enumerate(age_order)}
lang_counts['Language'] = lang_counts['Language'].str.strip()
languages = sorted(lang_counts['Language'].unique(), key=lambda x: x.lower())

lang_to_y = {lang: i for i, lang in enumerate(languages)}

lang_counts['y'] = lang_counts['Language'].map(lang_to_y)
lang_counts['x'] = lang_counts['Age'].map(age_to_x)
sizes = np.sqrt(lang_counts['Count']) * 6

fig, ax = plt.subplots(figsize=(16, 12))

scatter = ax.scatter(
    lang_counts['x'],
    lang_counts['y'],
    s=sizes,
    alpha=0.6,
    c=lang_counts['Count'],  # Color by count
    cmap='viridis',
    edgecolors='black',
    linewidth=0.5
)
plt.xticks(list(age_to_x.values()), list(age_to_x.keys()), rotation=45, fontsize=14)
plt.yticks(list(lang_to_y.values()), list(lang_to_y.keys()), fontsize=14)
plt.title('BubblePlot: Programming Languages popularity across Ages with size: Freq')

plt.xlabel('Age Group')
plt.ylabel('Programming Languages worked with')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/3387504819.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['Language'] = df_3['LanguageHaveWorkedWith'].str.split(';')

# %% [markdown]
# #### 2. Bubble Plot for Preferred Databases vs. Job Satisfaction
#
# - Explore the relationship between preferred databases (`DatabaseWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to indicate the number of respondents for each database.

# %%
##Write your code here
df_4 = df[['JobSat', 'DatabaseWantToWorkWith']]
df_4.dropna(inplace=True)
df_4['Database'] = df_4['DatabaseWantToWorkWith'].str.split(';')
df_4 = df_4.explode('Database')
df_4['Database'] = df_4['Language'].str.strip()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_41371/2690934368.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4.dropna(inplace=True)
# DatabaseWantToWorkWith
# PostgreSQL                                                                                                                                                         3738
# PostgreSQL;SQLite                                                                                                                                                  1533
# SQLite                                                                                                                                                             1476
# ...

# %% [markdown]
# ### Task 3: Comparing Data Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Compensation Across Developer Roles
#
# - Visualize compensation (`ConvertedCompYearly`) across different developer roles (`DevType`).
#
# - Use bubble size to represent job satisfaction.

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Collaboration Tools by Age
#
# - Visualize the relationship between the collaboration tools used (`NEWCollabToolsHaveWorkedWith`) and age groups.
#
# - Use bubble size to represent the frequency of tool usage.

# %%
##Write your code here

# %% [markdown]
# ### Task 4: Visualizing Technology Trends Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Preferred Web Frameworks vs. Job Satisfaction
#
# - Explore the relationship between preferred web frameworks (`WebframeWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to represent the number of respondents.

# %%
##Write your code here

# %% [markdown]
# #### 2. Bubble Plot for Admired Technologies Across Countries
#
# - Visualize the distribution of admired technologies (`LanguageAdmired`) across different countries (`Country`).
#
# - Use bubble size to represent the frequency of admiration.

# %%
##Write your code here

# %% [markdown]
# ## Final Step: Review

# %% [markdown]
# After completing the lab, you will have extensively used bubble plots to gain insights into developer community preferences, demographics, compensation trends, and job satisfaction.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
#
# - Create and interpret bubble plots to analyze relationships and compositions within datasets.
#
# - Use bubble plots to explore developer preferences, compensation trends, and satisfaction levels.
#
# - Apply bubble plots to visualize complex relationships involving multiple dimensions effectively.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
## Write your code here
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}

df['Age'] = df['Age'].map(age_mapping)
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['JobSatPoints_6'] = pd.to_numeric(df['JobSatPoints_6'], errors='coerce')

plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['JobSatPoints_6'], alpha=0.6)
plt.title('ScatterPlot Rltn btw Age and Job Satisfaction')
plt.xlabel('Age: Numeric')
plt.ylabel('Job Sat: Numeric')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
## Write your code here
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce')
df['JobSatPoints_6'] = pd.to_numeric(df['JobSatPoints_6'], errors='coerce')

plt.figure(figsize=(8, 6))
plt.scatter(df['JobSatPoints_6'], df['ConvertedCompYearly'], alpha=0.6)
plt.title('ScatterPlot Rltn btw Yearly Comp and Job Satisfaction')
plt.ylabel('ConvertedCompYearly: Numeric')
plt.xlabel('Job Sat: Numeric')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
## Write your code here
import numpy as np
df1 = pd.read_csv(file_path)
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}

df1['Age'] = df1['Age'].map(age_mapping)
df_new = df1[['JobSatPoints_6', 'Age']]
df_new.dropna(inplace=True)

x = df_new['Age']
y = df_new['JobSatPoints_6']

m, b = np.polyfit(x, y, 1)
plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.5)

# Regression
plt.plot(x, m*x + b, color='red', linewidth=2)
plt.title('ScatterPlot: Job Satisfaction vs Age with Trend Line')
plt.ylabel('Job Satisfaction')
plt.xlabel('Age: Numeric')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/4066656313.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.dropna(inplace=True)

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
## Write your code here
df2 = pd.read_csv(file_path)
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}

df2['YearsCodePro'] = (
    df2['YearsCodePro'].replace(
        {"Less than 1 year": 0, "More than 50 years" : 51}
    ).astype(float)
)

df2['Age'] = df2['Age'].map(age_mapping)
df_new1 = df2[['YearsCodePro', 'Age']]
df_new1.dropna(inplace=True)

x = df_new1['Age']
y = df_new1['YearsCodePro']

plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.5)

plt.title('ScatterPlot: Years of Pro-Coding vs Age with Trend Line')
plt.ylabel('YearsCodePro')
plt.xlabel('Age: Numeric')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/3004961066.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1.dropna(inplace=True)

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
## Write your code here
df3 = pd.read_csv(file_path)
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}


df3['Age'] = df3['Age'].map(age_mapping)
df_new2 = df3[['ConvertedCompYearly', 'JobSatPoints_6', 'Age']]
df_new2.dropna(inplace=True)

plt.figure(figsize=(8, 6))
plt.scatter(df_new2['ConvertedCompYearly'], 
            df_new2['JobSatPoints_6'], 
            s=df_new2['Age'], alpha=0.5)

plt.title('BubblePlot: Comp vs Job Sat with Bubble=Age')
plt.ylabel('JobSatPoints_6')
plt.xlabel('ConvertedCompYearly')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/2567247932.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new2.dropna(inplace=True)

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
## Write your code here
df4 = pd.read_csv(file_path)
df_new4 = df4[['LanguageHaveWorkedWith', 'JobSatPoints_6']]
df_new4['LanguageHaveWorkedWith'] = df_new4['LanguageHaveWorkedWith'].str.split(';')
df_new4 = df_new4.explode('LanguageHaveWorkedWith')
df_new4.dropna(inplace=True)
df_new4['LanguageHaveWorkedWith'] = df_new4['LanguageHaveWorkedWith'].str.strip()
df_new4['LangCode'] = df_new4['LanguageHaveWorkedWith'].astype('category').cat.codes

plt.figure(figsize=(12, 6))
plt.scatter(df_new4['LangCode'], 
            df_new4['JobSatPoints_6'], 
            alpha=0.5)

plt.title('ScatterPlot: Lang encoded vs Job Sat')
plt.ylabel('JobSatPoints_6')
plt.xlabel('Encoded programming Languages')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/3515026260.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new4['LanguageHaveWorkedWith'] = df_new4['LanguageHaveWorkedWith'].str.split(';')

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
## Write your code here
df5 = pd.read_csv(file_path)
df_new5 = df5[['ConvertedCompYearly', 'JobSatPoints_6', 'Employment']]
df_new5['Employment'] = df_new5['Employment'].str.split(';')
df_new5 = df_new5.explode('Employment')
df_new5.dropna(inplace=True)
df_new5['Employment'] = df_new5['Employment'].str.strip()
df_new5['EmpCode'] = df_new5['Employment'].astype('category').cat.codes

upper = df_new5['ConvertedCompYearly'].quantile(0.99)
df_new5 = df_new5[df_new5['ConvertedCompYearly'] <= upper]

plt.figure(figsize=(12, 6))
plt.scatter(df_new5['ConvertedCompYearly'], 
            df_new5['JobSatPoints_6'],
            c=df_new5['EmpCode'],
            alpha=0.5)

plt.title('ScatterPlot: Comp yearly vs Job Sat with ColorCode: EmploymentType')
plt.ylabel('JobSatPoints_6')
plt.xlabel('ConvertedCompYearly')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/1131052559.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new5['Employment'] = df_new5['Employment'].str.split(';')

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
## Write your code here
df6 = pd.read_csv(file_path)
df_new6 = df6[['YearsCodePro', 'Age', 'Country']]
df_new6.dropna(inplace=True)
age_mapping = {
    'Under 18 years old': 17,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70,
    'Prefer not to say': None
}
df_new6['YearsCodePro'] = (
    df_new6['YearsCodePro'].replace(
        {"Less than 1 year": 0, "More than 50 years" : 51}
    ).astype(float)
)

df_new6['Age'] = df_new6['Age'].map(age_mapping)
df_new6['CountryCode'] = df_new6['Country'].astype('category').cat.codes

plt.figure(figsize=(12, 6))
plt.scatter(df_new6['YearsCodePro'], 
            df_new6['Age'],
            c=df_new6['CountryCode'],
            alpha=0.5)

plt.title('ScatterPlot: Years of Pro-Coding vs Age with ColorCode: CountryType')
plt.ylabel('YearsCodePro')
plt.xlabel('Age')
plt.grid(True)
plt.show()
# Out:
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/270692262.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new6.dropna(inplace=True)
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/270692262.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new6['YearsCodePro'] = (
# /var/folders/0l/pvtw36_j26v20v1h4xc53l940000gn/T/ipykernel_18166/270692262.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
